# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Other packages

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, chi2
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import KFold

# %% [markdown]
# # Loading datasets and processing the data

# %%
train=pd.read_csv('full_train.csv')
sentiment=pd.read_csv('concatenated_sentiment_ff.csv')

# %%
train.head()
# Out:
#          Date       CL=F        GC=F    HG=F       JPY=X   SI=F          ^DJI  \
# 0  2000-08-30  33.400002  273.899994  0.8850  106.610001  4.930  11103.009766
# 1  2000-08-31  33.099998  278.299988  0.8850  106.669998  5.003  11215.099609
# 2  2000-09-01  33.380001  277.000000  0.8890  105.949997  5.004  11238.780273
# 3  2000-09-05  33.799999  275.799988  0.9060  105.860001  4.998  11260.610352
# 4  2000-09-06  34.950001  274.200012  0.9015  105.930000  4.983  11310.639648
#
#          ^GSPC        ^IXIC        ^RUT   ^TNX   ^TYX       ^VIX  target
# 0  1502.589966  4103.810059  532.330017  5.800  5.736  17.690001       1
# 1  1517.680054  4206.350098  537.890015  5.729  5.674  16.840000       1
# 2  1520.770020  4234.330078  541.909973  5.675  5.655  17.530001       0
# 3  1507.079956  4143.180176  539.020020  5.683  5.663  19.820000       0
# 4  1492.250000  4013.340088  536.320007  5.712  5.700  20.790001       1

# %%
sentiment.head()
# Out:
#          Date                                              Title Sentiment
# 0  2010-01-04  Global Stocks and Commodities Rally on First T...  positive
# 1  2010-01-04  Dollar Slumps Amid Worldwide Manufacturing Imp...  negative
# 2  2010-01-04  Oil Prices Surge Above $81 a Barrel Due to U.S...  negative
# 3  2010-01-04  S&P 500 Sees 1.6 Percent Increase, Hits 15-Mon...  positive
# 4  2010-01-04  Argentina's Merval Index Reaches Record High, ...  positive

# %% [markdown]
# - We need to create a numerical signal from the Sentiment column (ideally between -1 and 1) to give a general sentiment about the day.
# - We have the generic, widely used signal in literature ie S=(number of positive-number of negative)/total number.
# - We tried experimenting with a weighted sum as well ie S=(lambda x number of positive-(1-lambda) x number of negative)/(lambda x number of positive+(1-lambda)number of negative).
# Here lambda>0.5 would mean that the agents have an optimistic point of view/risk-taking approach (negative news wouldn't have as much effect as positive news), whereas lambda<0.5 would mean that the agents have a pessimistic point of view/conservative approach.

# %%
def signal_func(L): #signal used in literature
    S=0
    for ch in L:
        if ch=='positive':
            S+=1
        if ch=='negative':
            S-=1
    return S/len(L)
def weighted_sum(L,lamda=0.5): #weighted sum
    S_p=S_n=0
    for ch in L:
        if ch=='positive':
            S_p+=lamda
        if ch=='negative':
            S_n+=1-lamda
    if S_p==S_n==0:
        return 0
    return (S_p-S_n)/len(L)

# %% [markdown]
# First, we tried the non-weighted sum.

# %%
#grouping by date and applying the signal_func to the results of sentiment analysis for each day
sentiment_result = sentiment.groupby('Date')['Sentiment'].apply(signal_func).reset_index()

# %% [markdown]
# Now we can merge all the necessary data in a big dataset

# %%
#changing the Date column to datetime to ensure correct merge
sentiment_result['Date']=pd.to_datetime(sentiment_result['Date'].values)
train['Date']=pd.to_datetime(train['Date'].values)
#inner join on Date
train=pd.merge(sentiment_result, train, on='Date', how='inner')

# %%
train
# Out:
#           Date  Sentiment       CL=F         GC=F    HG=F       JPY=X  \
# 0   2000-09-11  -1.000000  35.099998   273.100006  0.9130  106.089996
# 1   2000-09-29  -1.000000  30.860001   273.600006  0.9155  108.129997
# 2   2000-10-03   0.000000  32.070000   271.600006  0.8985  108.889999
# 3   2000-10-12  -1.000000  36.099998   276.399994  0.8795  107.750000
# 4   2000-10-17  -1.000000  32.950001   271.100006  0.8805  107.910004
# ..         ...        ...        ...          ...     ...         ...
# 852 2011-07-29  -0.812500  95.699997  1628.300049  4.4740   77.730003
# 853 2011-08-01  -0.500000  94.889999  1619.000000  4.4040   77.212997
# 854 2011-08-02  -0.785714  93.790001  1641.900024  4.3890   77.459999
# 855 2011-08-03  -0.310345  91.930000  1663.400024  4.3200   77.334999
# 856 2011-08-04  -0.675676  86.629997  1656.199951  4.2310   77.112000
#
#           SI=F          ^DJI        ^GSPC        ^IXIC        ^RUT   ^TNX  \
# 0     4.885000  11195.490234  1489.260010  3896.350098  533.619995  5.758
# 1     4.899000  10650.919922  1436.510010  3672.820068  521.369995  5.778
# 2     4.913000  10719.740234  1426.459961  3455.830078  504.670013  5.867
# 3     4.923000  10034.580078  1329.780029  3074.679932  462.970001  5.715
# 4     4.843000  10089.709961  1349.969971  3213.959961  470.880005  5.665
# ..         ...           ...          ...          ...         ...    ...
# 852  40.091999  12143.240234  1292.280029  2756.379883  797.030029  2.805
# 853  39.298000  12132.490234  1286.939941  2744.610107  792.849976  2.740
# 854  40.081001  11866.620117  1254.050049  2669.239990  767.010010  2.624
# 855  41.747002  11896.440430  1260.339966  2693.070068  772.780029  2.599
# 856  39.417999  11383.679688  1200.069946  2556.389893  726.799988  2.458
#
#       ^TYX       ^VIX  target
# 0    5.721  18.400000       0
# 1    5.869  20.570000       0
# 2    5.945  21.850000       1
# 3    5.809  30.510000       1
# 4    5.761  27.840000       0
# ..     ...        ...     ...
# 852  4.132  25.250000       0
# 853  4.071  23.660000       0
# 854  3.919  24.790001       1
# 855  3.873  23.379999       0
# 856  3.722  31.660000       0
#
# [857 rows x 15 columns]

# %% [markdown]
# Feature selection

# %% [markdown]
# We experimented with keeping and eliminating features manually and we found that removing 'SI=F' yielded the best results for us.

# %%
L=list(train.columns)
L.remove('Date')
L.remove('target')
L.remove('SI=F') 
X=train[L]
Y=train['target']

# %% [markdown]
# Splitting training data into training set and validation set.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %% [markdown]
# We tried using a scikit learn function for feature selection as well but it didn't yield better results.

# %%
#selector = SelectKBest(score_func=chi2, k=10)
#X_train_selected = selector.fit_transform(X_train, Y_train)
#X_test_selected = selector.transform(X_test)

# %% [markdown]
# # Trying classical machine learning classification algorithms: Decision tree, random forest, xgboost, logistic regression

# %% [markdown]
# Throughout this process we'll finetune the hyperparameters with the optuna library

# %% [markdown]
# ## Decision tree

# %%
#checking the performance without specifying the parameters
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
score=f1_score(Y_test, Y_pred)
print('f1 score=', score)
# Out:
# f1 score= 0.5989847715736041

# %%
#selecting the best hyperparameters
def objective_dec_tree(trial):
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)

    # Define the hyperparameter search space
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    splitter = trial.suggest_categorical('splitter', ['best', 'random'])
    max_depth = trial.suggest_int('max_depth', 1, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    
    # Initialize and train the model
    model = DecisionTreeClassifier(
        criterion=criterion,
        splitter=splitter,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    model.fit(X_train, Y_train)
    
    # Make predictions and evaluate the model
    preds = model.predict(X_valid)
    score=f1_score(Y_valid, preds)
    return score

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective_dec_tree, n_trials=100)

# Get the best parameters and best score
print("Best parameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2024-06-06 21:44:41,245] A new study created in memory with name: no-name-0bd7e8e3-34ce-43bb-b89b-39e47ae71ad7
# [I 2024-06-06 21:44:41,261] Trial 0 finished with value: 0.6153846153846154 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 1, 'min_samples_split': 15, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.6153846153846154.
# [I 2024-06-06 21:44:41,262] Trial 1 finished with value: 0.6311475409836066 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,284] Trial 2 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,292] Trial 3 finished with value: 0.6209677419354839 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,300] Trial 4 finished with value: 0.5686274509803921 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 19}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,313] Trial 5 finished with value: 0.5844748858447488 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 18}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,314] Trial 6 finished with value: 0.6209677419354839 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 2, 'min_samples_split': 12, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,341] Trial 7 finished with value: 0.5333333333333333 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,353] Trial 8 finished with value: 0.6153846153846154 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 1 with value: 0.6311475409836066.
# [I 2024-06-06 21:44:41,363] Trial 9 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,486] Trial 10 finished with value: 0.45569620253164556 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,529] Trial 11 finished with value: 0.6311475409836066 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,565] Trial 12 finished with value: 0.6311475409836066 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 13, 'min_samples_leaf': 6}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,593] Trial 13 finished with value: 0.6341463414634146 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 17, 'min_samples_leaf': 5}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,629] Trial 14 finished with value: 0.5029239766081871 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 8, 'min_samples_split': 20, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,668] Trial 15 finished with value: 0.5064935064935064 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 31, 'min_samples_split': 17, 'min_samples_leaf': 5}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,692] Trial 16 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,717] Trial 17 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,733] Trial 18 finished with value: 0.5671641791044776 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,763] Trial 19 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,793] Trial 20 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,814] Trial 21 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,851] Trial 22 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,884] Trial 23 finished with value: 0.5714285714285714 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 12}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,914] Trial 24 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,934] Trial 25 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,963] Trial 26 finished with value: 0.5853658536585366 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:41,992] Trial 27 finished with value: 0.5756097560975609 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,021] Trial 28 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,043] Trial 29 finished with value: 0.6153846153846154 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 1, 'min_samples_split': 15, 'min_samples_leaf': 12}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,075] Trial 30 finished with value: 0.6311475409836066 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 4, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,101] Trial 31 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,123] Trial 32 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,152] Trial 33 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 11}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,183] Trial 34 finished with value: 0.5688073394495413 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,212] Trial 35 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,232] Trial 36 finished with value: 0.6209677419354839 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,262] Trial 37 finished with value: 0.5728643216080402 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,283] Trial 38 finished with value: 0.5688073394495413 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,312] Trial 39 finished with value: 0.5172413793103449 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 10}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,346] Trial 40 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,378] Trial 41 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,407] Trial 42 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,433] Trial 43 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,471] Trial 44 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,502] Trial 45 finished with value: 0.5294117647058824 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,532] Trial 46 finished with value: 0.5714285714285714 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,558] Trial 47 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 11}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,592] Trial 48 finished with value: 0.4939759036144578 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 30, 'min_samples_split': 9, 'min_samples_leaf': 8}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,613] Trial 49 finished with value: 0.6209677419354839 and parameters: {'criterion': 'gini', 'splitter': 'random', 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,642] Trial 50 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,662] Trial 51 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,694] Trial 52 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,718] Trial 53 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,752] Trial 54 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,782] Trial 55 finished with value: 0.5728643216080402 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,815] Trial 56 finished with value: 0.5026178010471204 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,848] Trial 57 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,872] Trial 58 finished with value: 0.6311475409836066 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,902] Trial 59 finished with value: 0.5853658536585366 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,933] Trial 60 finished with value: 0.6311475409836066 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 5, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,963] Trial 61 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:42,997] Trial 62 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,022] Trial 63 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 12}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,052] Trial 64 finished with value: 0.45569620253164556 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,083] Trial 65 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,114] Trial 66 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,139] Trial 67 finished with value: 0.5688073394495413 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,171] Trial 68 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,192] Trial 69 finished with value: 0.5026178010471204 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,227] Trial 70 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 18, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,256] Trial 71 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,289] Trial 72 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,328] Trial 73 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,359] Trial 74 finished with value: 0.5157894736842106 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,391] Trial 75 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 12, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,432] Trial 76 finished with value: 0.45569620253164556 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,473] Trial 77 finished with value: 0.5754716981132075 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,503] Trial 78 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 12}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,531] Trial 79 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,557] Trial 80 finished with value: 0.5510204081632653 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,583] Trial 81 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,611] Trial 82 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,632] Trial 83 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,664] Trial 84 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,693] Trial 85 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,733] Trial 86 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,764] Trial 87 finished with value: 0.5728643216080402 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,793] Trial 88 finished with value: 0.6311475409836066 and parameters: {'criterion': 'gini', 'splitter': 'best', 'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,833] Trial 89 finished with value: 0.5 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,864] Trial 90 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 16}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,891] Trial 91 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,921] Trial 92 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,953] Trial 93 finished with value: 0.5139664804469274 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:43,973] Trial 94 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 14}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:44,008] Trial 95 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 18}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:44,053] Trial 96 finished with value: 0.5026178010471204 and parameters: {'criterion': 'entropy', 'splitter': 'random', 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 19}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:44,082] Trial 97 finished with value: 0.4567901234567901 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 20}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:44,113] Trial 98 finished with value: 0.6386554621848739 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 17}. Best is trial 9 with value: 0.6386554621848739.
# [I 2024-06-06 21:44:44,139] Trial 99 finished with value: 0.5728643216080402 and parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 15}. Best is trial 9 with value: 0.6386554621848739.
# Best parameters: {'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 20}
# Best score: 0.6386554621848739

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestClassifier()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
score=f1_score(Y_test, Y_pred)
print('f1 score=', score)
# Out:
# f1 score= 0.59375

# %%
def objective_random_forest(trial):
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)
    # Define the hyperparameter search space
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    max_depth = trial.suggest_int('max_depth', 1, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])
    
    # Initialize and train the model
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        random_state=42
    )
    model.fit(X_train, Y_train)
    
    # Make predictions and evaluate the model
    preds = model.predict(X_valid)
    score=f1_score(Y_valid, preds)
    
    return score

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective_random_forest, n_trials=100)

# Get the best parameters and best score
print("Best parameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2024-06-06 21:49:55,693] A new study created in memory with name: no-name-88610a31-42ec-4908-b75c-7375e7a9d88c
# [I 2024-06-06 21:49:55,953] Trial 0 finished with value: 0.5866666666666667 and parameters: {'n_estimators': 190, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 0 with value: 0.5866666666666667.
# [I 2024-06-06 21:49:56,235] Trial 1 finished with value: 0.5157894736842106 and parameters: {'n_estimators': 90, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 14, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.5866666666666667.
# [I 2024-06-06 21:49:56,348] Trial 2 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 91, 'max_depth': 1, 'min_samples_split': 19, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:56,496] Trial 3 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 143, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:56,633] Trial 4 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 102, 'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:56,922] Trial 5 finished with value: 0.5882352941176471 and parameters: {'n_estimators': 130, 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:57,057] Trial 6 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 85, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:57,707] Trial 7 finished with value: 0.48148148148148145 and parameters: {'n_estimators': 105, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,058] Trial 8 finished with value: 0.5632183908045977 and parameters: {'n_estimators': 133, 'max_depth': 31, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,224] Trial 9 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 159, 'max_depth': 1, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,264] Trial 10 finished with value: 0.5130890052356021 and parameters: {'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,344] Trial 11 finished with value: 0.5929203539823009 and parameters: {'n_estimators': 55, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,534] Trial 12 finished with value: 0.5829596412556054 and parameters: {'n_estimators': 159, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,614] Trial 13 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 70, 'max_depth': 1, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,703] Trial 14 finished with value: 0.4919786096256685 and parameters: {'n_estimators': 39, 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:58,914] Trial 15 finished with value: 0.6090909090909091 and parameters: {'n_estimators': 136, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:59,164] Trial 16 finished with value: 0.5929203539823009 and parameters: {'n_estimators': 200, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:59,479] Trial 17 finished with value: 0.5133689839572193 and parameters: {'n_estimators': 166, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:59,642] Trial 18 finished with value: 0.5919282511210763 and parameters: {'n_estimators': 114, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:49:59,803] Trial 19 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 175, 'max_depth': 1, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,083] Trial 20 finished with value: 0.5291005291005291 and parameters: {'n_estimators': 144, 'max_depth': 12, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,227] Trial 21 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 116, 'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,354] Trial 22 finished with value: 0.6324786324786325 and parameters: {'n_estimators': 86, 'max_depth': 2, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,464] Trial 23 finished with value: 0.600896860986547 and parameters: {'n_estimators': 72, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,553] Trial 24 finished with value: 0.6276150627615062 and parameters: {'n_estimators': 49, 'max_depth': 2, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,693] Trial 25 finished with value: 0.5660377358490566 and parameters: {'n_estimators': 83, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,759] Trial 26 finished with value: 0.6180257510729614 and parameters: {'n_estimators': 26, 'max_depth': 2, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:00,884] Trial 27 finished with value: 0.5675675675675675 and parameters: {'n_estimators': 67, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:01,334] Trial 28 finished with value: 0.6181818181818182 and parameters: {'n_estimators': 98, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:01,496] Trial 29 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 117, 'max_depth': 1, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:01,724] Trial 30 finished with value: 0.5753424657534246 and parameters: {'n_estimators': 147, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:01,843] Trial 31 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 98, 'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:01,953] Trial 32 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 81, 'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,141] Trial 33 finished with value: 0.6086956521739131 and parameters: {'n_estimators': 122, 'max_depth': 2, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,307] Trial 34 finished with value: 0.6212765957446809 and parameters: {'n_estimators': 103, 'max_depth': 1, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,434] Trial 35 finished with value: 0.6329113924050633 and parameters: {'n_estimators': 92, 'max_depth': 2, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,583] Trial 36 finished with value: 0.579185520361991 and parameters: {'n_estimators': 89, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 14, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,794] Trial 37 finished with value: 0.5583756345177665 and parameters: {'n_estimators': 59, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:02,953] Trial 38 finished with value: 0.6212765957446809 and parameters: {'n_estimators': 108, 'max_depth': 2, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:03,092] Trial 39 finished with value: 0.6027397260273972 and parameters: {'n_estimators': 81, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:03,544] Trial 40 finished with value: 0.5473684210526316 and parameters: {'n_estimators': 125, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 19, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:03,683] Trial 41 finished with value: 0.6297872340425532 and parameters: {'n_estimators': 91, 'max_depth': 2, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:03,883] Trial 42 finished with value: 0.5053763440860215 and parameters: {'n_estimators': 94, 'max_depth': 17, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,143] Trial 43 finished with value: 0.5363128491620112 and parameters: {'n_estimators': 109, 'max_depth': 22, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,224] Trial 44 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 74, 'max_depth': 1, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,420] Trial 45 finished with value: 0.6017699115044248 and parameters: {'n_estimators': 136, 'max_depth': 2, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,524] Trial 46 finished with value: 0.6036036036036037 and parameters: {'n_estimators': 61, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,753] Trial 47 finished with value: 0.5714285714285714 and parameters: {'n_estimators': 130, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:04,987] Trial 48 finished with value: 0.542713567839196 and parameters: {'n_estimators': 102, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:05,242] Trial 49 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 182, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:05,376] Trial 50 finished with value: 0.5903083700440529 and parameters: {'n_estimators': 82, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:05,495] Trial 51 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 49, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.6337448559670782.
# [I 2024-06-06 21:50:05,697] Trial 52 finished with value: 0.6363636363636364 and parameters: {'n_estimators': 90, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:05,903] Trial 53 finished with value: 0.6363636363636364 and parameters: {'n_estimators': 92, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:06,074] Trial 54 finished with value: 0.6363636363636364 and parameters: {'n_estimators': 90, 'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:06,245] Trial 55 finished with value: 0.6302521008403361 and parameters: {'n_estimators': 91, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:06,563] Trial 56 finished with value: 0.5077720207253886 and parameters: {'n_estimators': 74, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:06,912] Trial 57 finished with value: 0.5373134328358209 and parameters: {'n_estimators': 110, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,082] Trial 58 finished with value: 0.611353711790393 and parameters: {'n_estimators': 67, 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,233] Trial 59 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 77, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,406] Trial 60 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 79, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,558] Trial 61 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 75, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,703] Trial 62 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 76, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,827] Trial 63 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 66, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:07,934] Trial 64 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 51, 'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:08,113] Trial 65 finished with value: 0.6302521008403361 and parameters: {'n_estimators': 98, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:08,333] Trial 66 finished with value: 0.5084745762711864 and parameters: {'n_estimators': 38, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:08,476] Trial 67 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 80, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:08,623] Trial 68 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 77, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:09,126] Trial 69 finished with value: 0.5057471264367817 and parameters: {'n_estimators': 86, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:09,442] Trial 70 finished with value: 0.5027932960893855 and parameters: {'n_estimators': 63, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:09,576] Trial 71 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 71, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:09,733] Trial 72 finished with value: 0.6302521008403361 and parameters: {'n_estimators': 96, 'max_depth': 1, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:09,864] Trial 73 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 57, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:10,032] Trial 74 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 87, 'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:10,203] Trial 75 finished with value: 0.6244725738396625 and parameters: {'n_estimators': 103, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:10,343] Trial 76 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 77, 'max_depth': 1, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:10,456] Trial 77 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 43, 'max_depth': 1, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:10,926] Trial 78 finished with value: 0.5056179775280899 and parameters: {'n_estimators': 85, 'max_depth': 17, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:11,093] Trial 79 finished with value: 0.6302521008403361 and parameters: {'n_estimators': 96, 'max_depth': 1, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:11,392] Trial 80 finished with value: 0.5235602094240838 and parameters: {'n_estimators': 76, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:11,503] Trial 81 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 65, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:11,894] Trial 82 finished with value: 0.4971751412429379 and parameters: {'n_estimators': 70, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:12,026] Trial 83 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 69, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:12,293] Trial 84 finished with value: 0.5106382978723404 and parameters: {'n_estimators': 55, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:12,452] Trial 85 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 88, 'max_depth': 1, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:12,603] Trial 86 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 80, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,014] Trial 87 finished with value: 0.5263157894736842 and parameters: {'n_estimators': 92, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,133] Trial 88 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 63, 'max_depth': 1, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,284] Trial 89 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 84, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,484] Trial 90 finished with value: 0.6186440677966102 and parameters: {'n_estimators': 114, 'max_depth': 1, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,633] Trial 91 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 79, 'max_depth': 1, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,764] Trial 92 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 71, 'max_depth': 1, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:13,903] Trial 93 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 76, 'max_depth': 1, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:14,053] Trial 94 finished with value: 0.6337448559670782 and parameters: {'n_estimators': 82, 'max_depth': 1, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:14,553] Trial 95 finished with value: 0.4883720930232558 and parameters: {'n_estimators': 90, 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:14,729] Trial 96 finished with value: 0.6244725738396625 and parameters: {'n_estimators': 103, 'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:15,289] Trial 97 finished with value: 0.5310734463276836 and parameters: {'n_estimators': 99, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:15,424] Trial 98 finished with value: 0.6311475409836066 and parameters: {'n_estimators': 67, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# [I 2024-06-06 21:50:15,875] Trial 99 finished with value: 0.5113636363636364 and parameters: {'n_estimators': 74, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6363636363636364.
# Best parameters: {'n_estimators': 90, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}
# Best score: 0.6363636363636364

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# For the logistic regression, we experimented with the LASSO and RIDGE penalizations and selected the best performing one and the best hyperparameter with optuna.

# %%
model_regress = LogisticRegression()
model_regress.fit(X_train, Y_train)
Y_pred = model_regress.predict(X_test)
score=f1_score(Y_test, np.round(Y_pred))
print('f1 score=', score)
# Out:
# f1 score= 0.6521739130434783
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
def objective_regress(trial):
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)

    # Define the hyperparameter search space
    C = trial.suggest_loguniform('C', 1e-4, 1e4)
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
    solver = 'liblinear' if penalty == 'l1' else 'lbfgs'
    
    # Initialize and train the model
    model = LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=10000)
    model.fit(X_train, Y_train)
    
    # Make predictions and evaluate the model
    preds = model.predict(X_valid)
    score=f1_score(Y_valid, preds)
    return score

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective_regress, n_trials=100)

# Get the best parameters and best score
print("Best parameters (Optuna):", study.best_params)
print("Best score (Optuna):", study.best_value)

# Evaluate on the test set
best_optuna_model = LogisticRegression(**study.best_params, solver='liblinear' if study.best_params['penalty'] == 'l1' else 'lbfgs', max_iter=10000)
best_optuna_model.fit(X_train, Y_train)
Y_pred = best_optuna_model.predict(X_test)
print("Test Accuracy (Optuna):", f1_score(Y_test, Y_pred))
# Out:
# [I 2024-06-06 22:06:14,560] A new study created in memory with name: no-name-569e6cee-2e0e-448a-9075-78111892f554
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:14,932] Trial 0 finished with value: 0.5964912280701754 and parameters: {'C': 0.0006157450990732934, 'penalty': 'l2'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:15,178] Trial 1 finished with value: 0.56 and parameters: {'C': 678.3814316528747, 'penalty': 'l1'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:15,320] Trial 2 finished with value: 0.56 and parameters: {'C': 2524.980029072977, 'penalty': 'l1'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:16,340] Trial 3 finished with value: 0.5607476635514018 and parameters: {'C': 3.3218775627694157, 'penalty': 'l2'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:16,567] Trial 4 finished with value: 0.56 and parameters: {'C': 733.7546931754358, 'penalty': 'l1'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:17,513] Trial 5 finished with value: 0.5687203791469194 and parameters: {'C': 569.9531776774091, 'penalty': 'l2'}. Best is trial 0 with value: 0.5964912280701754.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:17,520] Trial 6 finished with value: 0.6311475409836066 and parameters: {'C': 0.000313909398954891, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:17,860] Trial 7 finished with value: 0.5866666666666667 and parameters: {'C': 0.0022353874383903385, 'penalty': 'l2'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:18,715] Trial 8 finished with value: 0.5544554455445545 and parameters: {'C': 2.910113613258335, 'penalty': 'l2'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:19,567] Trial 9 finished with value: 0.5514018691588785 and parameters: {'C': 23.39837955909518, 'penalty': 'l2'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:19,725] Trial 10 finished with value: 0.6167400881057269 and parameters: {'C': 0.038206665412731204, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:19,771] Trial 11 finished with value: 0.6133333333333333 and parameters: {'C': 0.012670461690683367, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:19,925] Trial 12 finished with value: 0.6228070175438597 and parameters: {'C': 0.03684768741146274, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,181] Trial 13 finished with value: 0.591304347826087 and parameters: {'C': 0.09854068263607849, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,194] Trial 14 finished with value: 0.6285714285714286 and parameters: {'C': 0.0002836487963885364, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,205] Trial 15 finished with value: 0.6311475409836066 and parameters: {'C': 0.00033465552678797647, 'penalty': 'l1'}. Best is trial 6 with value: 0.6311475409836066.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,216] Trial 16 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010030785637449065, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,230] Trial 17 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010574140100665482, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,244] Trial 18 finished with value: 0.6133333333333333 and parameters: {'C': 0.004083152067768661, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,252] Trial 19 finished with value: 0.6349206349206349 and parameters: {'C': 0.00011110673931017946, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,571] Trial 20 finished with value: 0.5622119815668203 and parameters: {'C': 0.2700312955498593, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,582] Trial 21 finished with value: 0.6349206349206349 and parameters: {'C': 0.00017197296190251651, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,597] Trial 22 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010548395026639534, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,610] Trial 23 finished with value: 0.6194690265486725 and parameters: {'C': 0.002173560283659133, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,630] Trial 24 finished with value: 0.6255506607929515 and parameters: {'C': 0.001602071511969344, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,662] Trial 25 finished with value: 0.6222222222222222 and parameters: {'C': 0.008040853489212166, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,675] Trial 26 finished with value: 0.6133333333333333 and parameters: {'C': 0.0008808707709083754, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,682] Trial 27 finished with value: 0.6349206349206349 and parameters: {'C': 0.000112502142548642, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:20,862] Trial 28 finished with value: 0.5572139303482587 and parameters: {'C': 25.409405545234833, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,160] Trial 29 finished with value: 0.5964912280701754 and parameters: {'C': 0.0005766173214710103, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,211] Trial 30 finished with value: 0.6167400881057269 and parameters: {'C': 0.00971376519055675, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,220] Trial 31 finished with value: 0.6349206349206349 and parameters: {'C': 0.00013222632752744388, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,232] Trial 32 finished with value: 0.6194690265486725 and parameters: {'C': 0.0007417906757462252, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,245] Trial 33 finished with value: 0.6349206349206349 and parameters: {'C': 0.0001002540754777469, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,260] Trial 34 finished with value: 0.6167400881057269 and parameters: {'C': 0.0004407481036267974, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,272] Trial 35 finished with value: 0.6194690265486725 and parameters: {'C': 0.001276432029425124, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,291] Trial 36 finished with value: 0.6133333333333333 and parameters: {'C': 0.0032062825698310374, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,481] Trial 37 finished with value: 0.5938864628820961 and parameters: {'C': 0.00026934686311375013, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:21,620] Trial 38 finished with value: 0.56 and parameters: {'C': 5215.192193658688, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:22,494] Trial 39 finished with value: 0.5673076923076923 and parameters: {'C': 0.2919458424018874, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,509] Trial 40 finished with value: 0.632 and parameters: {'C': 0.0002489552411596178, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,522] Trial 41 finished with value: 0.6349206349206349 and parameters: {'C': 0.00011347244815112296, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,530] Trial 42 finished with value: 0.6133333333333333 and parameters: {'C': 0.0007743536538625978, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,544] Trial 43 finished with value: 0.6349206349206349 and parameters: {'C': 0.00019576889768124664, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,561] Trial 44 finished with value: 0.6133333333333333 and parameters: {'C': 0.004083004371729912, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:22,734] Trial 45 finished with value: 0.5527638190954773 and parameters: {'C': 54.660139995622245, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:23,625] Trial 46 finished with value: 0.5765765765765766 and parameters: {'C': 0.02086357323501498, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:23,626] Trial 47 finished with value: 0.6167400881057269 and parameters: {'C': 0.0004952125363575647, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:23,826] Trial 48 finished with value: 0.5797101449275363 and parameters: {'C': 3.3768755892059215, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:23,843] Trial 49 finished with value: 0.6194690265486725 and parameters: {'C': 0.0012544561675597813, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# c:\Users\Bechir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2024-06-06 22:06:24,760] Trial 50 finished with value: 0.5607476635514018 and parameters: {'C': 285.95756181847423, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,765] Trial 51 finished with value: 0.6349206349206349 and parameters: {'C': 0.0001173745760956039, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,781] Trial 52 finished with value: 0.6349206349206349 and parameters: {'C': 0.00022409769481451837, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,796] Trial 53 finished with value: 0.6297872340425532 and parameters: {'C': 0.00038431296684202494, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,796] Trial 54 finished with value: 0.6349206349206349 and parameters: {'C': 0.0001761115947200274, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,815] Trial 55 finished with value: 0.6167400881057269 and parameters: {'C': 0.0005037515751769509, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,834] Trial 56 finished with value: 0.6194690265486725 and parameters: {'C': 0.00212403412299111, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,858] Trial 57 finished with value: 0.6160714285714286 and parameters: {'C': 0.006138853862970022, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,867] Trial 58 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010377021765634087, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,877] Trial 59 finished with value: 0.6194690265486725 and parameters: {'C': 0.00098761810869366, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,898] Trial 60 finished with value: 0.6349206349206349 and parameters: {'C': 0.0002260222361023144, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,908] Trial 61 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010207112284660274, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,915] Trial 62 finished with value: 0.6349206349206349 and parameters: {'C': 0.00019315678663317276, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,935] Trial 63 finished with value: 0.6329113924050633 and parameters: {'C': 0.00037391959623928587, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,948] Trial 64 finished with value: 0.6194690265486725 and parameters: {'C': 0.0006426183551985143, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,967] Trial 65 finished with value: 0.6349206349206349 and parameters: {'C': 0.00018279884876530833, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:24,976] Trial 66 finished with value: 0.6255506607929515 and parameters: {'C': 0.0016244794837701809, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,209] Trial 67 finished with value: 0.5938864628820961 and parameters: {'C': 0.00034167312250495954, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,227] Trial 68 finished with value: 0.6349206349206349 and parameters: {'C': 0.00016400987490391885, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,246] Trial 69 finished with value: 0.6194690265486725 and parameters: {'C': 0.0007046927725274021, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,544] Trial 70 finished with value: 0.5660377358490566 and parameters: {'C': 1.599808693438288, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,561] Trial 71 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010384919136187242, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,570] Trial 72 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010314403622798993, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,580] Trial 73 finished with value: 0.6311475409836066 and parameters: {'C': 0.000346671297964751, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,596] Trial 74 finished with value: 0.6349206349206349 and parameters: {'C': 0.00016419841323569407, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,615] Trial 75 finished with value: 0.6194690265486725 and parameters: {'C': 0.0010910341035341297, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,631] Trial 76 finished with value: 0.6133333333333333 and parameters: {'C': 0.002819452887016161, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,644] Trial 77 finished with value: 0.6285714285714286 and parameters: {'C': 0.0002912412730391639, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:25,914] Trial 78 finished with value: 0.5964912280701754 and parameters: {'C': 0.0005756019089069782, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,097] Trial 79 finished with value: 0.6 and parameters: {'C': 0.06869952329910621, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,110] Trial 80 finished with value: 0.6349206349206349 and parameters: {'C': 0.00015007313972592446, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,128] Trial 81 finished with value: 0.6349206349206349 and parameters: {'C': 0.00015859741270251565, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,132] Trial 82 finished with value: 0.6260162601626016 and parameters: {'C': 0.0002680159907976311, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,144] Trial 83 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010633957474091613, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,166] Trial 84 finished with value: 0.6200873362445415 and parameters: {'C': 0.00042205838976465724, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,180] Trial 85 finished with value: 0.632 and parameters: {'C': 0.00024887102358600393, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,193] Trial 86 finished with value: 0.6133333333333333 and parameters: {'C': 0.00079685716540135, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,201] Trial 87 finished with value: 0.6349206349206349 and parameters: {'C': 0.00015614645365286077, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,214] Trial 88 finished with value: 0.6255506607929515 and parameters: {'C': 0.001723172343865204, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,463] Trial 89 finished with value: 0.5964912280701754 and parameters: {'C': 0.0004553919134145626, 'penalty': 'l2'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,479] Trial 90 finished with value: 0.6349206349206349 and parameters: {'C': 0.0001461573152981457, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,498] Trial 91 finished with value: 0.6349206349206349 and parameters: {'C': 0.00024499279281810736, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,510] Trial 92 finished with value: 0.6349206349206349 and parameters: {'C': 0.00010173931876891102, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,510] Trial 93 finished with value: 0.6349206349206349 and parameters: {'C': 0.00022574492762214945, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,729] Trial 94 finished with value: 0.5615763546798029 and parameters: {'C': 9.008528301020313, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,731] Trial 95 finished with value: 0.6133333333333333 and parameters: {'C': 0.0005572201215601841, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,749] Trial 96 finished with value: 0.6311475409836066 and parameters: {'C': 0.0003184114047534445, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:26,763] Trial 97 finished with value: 0.6349206349206349 and parameters: {'C': 0.0001479229164480332, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:27,026] Trial 98 finished with value: 0.5753424657534246 and parameters: {'C': 0.19853997733508214, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# C:\Users\Bechir\AppData\Local\Temp\ipykernel_604\515648391.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4)
# [I 2024-06-06 22:06:27,040] Trial 99 finished with value: 0.6194690265486725 and parameters: {'C': 0.0010384641727038217, 'penalty': 'l1'}. Best is trial 16 with value: 0.6349206349206349.
# Best parameters (Optuna): {'C': 0.00010030785637449065, 'penalty': 'l1'}
# Best score (Optuna): 0.6349206349206349
# Test Accuracy (Optuna): 0.706766917293233

# %% [markdown]
# ## XGBoost

# %%
model_XGB = XGBClassifier()
model_XGB.fit(X_train, Y_train)
Y_pred = model_XGB.predict(X_test)
score=f1_score(Y_test, Y_pred)
print('f1 score=', score)
# Out:
# f1 score= 0.5698924731182796

# %%
def objective_XGB(trial):
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)
    
    param = {
        'verbosity': 0,
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'n_estimators': trial.suggest_int('n_estimators', 50, 200),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'max_depth': trial.suggest_int('max_depth', 3, 7),
        'subsample': trial.suggest_float('subsample', 0.8, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.8, 1.0)
    }
    
    model = XGBClassifier(**param)
    model.fit(X_train, Y_train)
    preds = model.predict(X_valid)
    score=f1_score(Y_valid, preds)
    
    return score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective_XGB, n_trials=100)

# Get the best parameters and best score
print("Best parameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2024-06-07 10:23:03,486] A new study created in memory with name: no-name-8776770c-135e-4637-9ee2-28ba4eea75df
# [I 2024-06-07 10:23:03,701] Trial 0 finished with value: 0.5402298850574713 and parameters: {'n_estimators': 196, 'learning_rate': 0.14647663230183336, 'max_depth': 5, 'subsample': 0.8727307269755952, 'colsample_bytree': 0.9545138707706515}. Best is trial 0 with value: 0.5402298850574713.
# [I 2024-06-07 10:23:03,854] Trial 1 finished with value: 0.5333333333333333 and parameters: {'n_estimators': 179, 'learning_rate': 0.05695711565935688, 'max_depth': 5, 'subsample': 0.9198395029258059, 'colsample_bytree': 0.8988396238789153}. Best is trial 0 with value: 0.5402298850574713.
# [I 2024-06-07 10:23:04,071] Trial 2 finished with value: 0.5573770491803278 and parameters: {'n_estimators': 194, 'learning_rate': 0.0263060024898018, 'max_depth': 6, 'subsample': 0.854227279798709, 'colsample_bytree': 0.8820982811707584}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,219] Trial 3 finished with value: 0.5454545454545454 and parameters: {'n_estimators': 106, 'learning_rate': 0.07224837868128715, 'max_depth': 6, 'subsample': 0.8699710830213906, 'colsample_bytree': 0.916743359333933}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,368] Trial 4 finished with value: 0.532608695652174 and parameters: {'n_estimators': 170, 'learning_rate': 0.04413678879295654, 'max_depth': 4, 'subsample': 0.8305650498306638, 'colsample_bytree': 0.9142870427635699}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,436] Trial 5 finished with value: 0.4861878453038674 and parameters: {'n_estimators': 74, 'learning_rate': 0.13701106945301525, 'max_depth': 4, 'subsample': 0.9032248088036302, 'colsample_bytree': 0.8139809342687081}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,536] Trial 6 finished with value: 0.5052631578947369 and parameters: {'n_estimators': 134, 'learning_rate': 0.042855818031925855, 'max_depth': 4, 'subsample': 0.866643895995868, 'colsample_bytree': 0.8806059211966111}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,641] Trial 7 finished with value: 0.5130890052356021 and parameters: {'n_estimators': 101, 'learning_rate': 0.03338419947125237, 'max_depth': 5, 'subsample': 0.888379644687139, 'colsample_bytree': 0.9045312409766206}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,801] Trial 8 finished with value: 0.5280898876404494 and parameters: {'n_estimators': 123, 'learning_rate': 0.14591185681783667, 'max_depth': 6, 'subsample': 0.9150812759714135, 'colsample_bytree': 0.882567636470098}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:04,889] Trial 9 finished with value: 0.5423728813559322 and parameters: {'n_estimators': 138, 'learning_rate': 0.1372418589519702, 'max_depth': 3, 'subsample': 0.9078077677829024, 'colsample_bytree': 0.8633365352674814}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:05,001] Trial 10 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 50, 'learning_rate': 0.19051097190681476, 'max_depth': 7, 'subsample': 0.9849090322427136, 'colsample_bytree': 0.8325967352787499}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:05,128] Trial 11 finished with value: 0.5363128491620112 and parameters: {'n_estimators': 60, 'learning_rate': 0.1978694883835687, 'max_depth': 7, 'subsample': 0.9977557307917008, 'colsample_bytree': 0.8254868458115077}. Best is trial 2 with value: 0.5573770491803278.
# [I 2024-06-07 10:23:05,260] Trial 12 finished with value: 0.5849056603773585 and parameters: {'n_estimators': 51, 'learning_rate': 0.012038901677598537, 'max_depth': 7, 'subsample': 0.9922887480466193, 'colsample_bytree': 0.8440292820840724}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:05,468] Trial 13 finished with value: 0.5658536585365853 and parameters: {'n_estimators': 158, 'learning_rate': 0.010391550276317146, 'max_depth': 6, 'subsample': 0.9553158970530237, 'colsample_bytree': 0.8469909809751052}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:05,701] Trial 14 finished with value: 0.5408163265306123 and parameters: {'n_estimators': 153, 'learning_rate': 0.012019762567473107, 'max_depth': 7, 'subsample': 0.960710790553683, 'colsample_bytree': 0.8475623143484929}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:05,839] Trial 15 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 83, 'learning_rate': 0.08732362466483815, 'max_depth': 6, 'subsample': 0.9471317006943721, 'colsample_bytree': 0.8078419206887517}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:06,085] Trial 16 finished with value: 0.5567010309278351 and parameters: {'n_estimators': 162, 'learning_rate': 0.011283239467025932, 'max_depth': 7, 'subsample': 0.9568398241724994, 'colsample_bytree': 0.9763572631968571}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:06,238] Trial 17 finished with value: 0.550561797752809 and parameters: {'n_estimators': 113, 'learning_rate': 0.10413182005422676, 'max_depth': 6, 'subsample': 0.9783329446937691, 'colsample_bytree': 0.8499356422069143}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:06,451] Trial 18 finished with value: 0.5621621621621622 and parameters: {'n_estimators': 148, 'learning_rate': 0.06558476963089344, 'max_depth': 7, 'subsample': 0.9344515738344145, 'colsample_bytree': 0.9349174920142941}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:06,568] Trial 19 finished with value: 0.5108695652173914 and parameters: {'n_estimators': 88, 'learning_rate': 0.08186783530019591, 'max_depth': 5, 'subsample': 0.9718073989030678, 'colsample_bytree': 0.8527616470274644}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:06,765] Trial 20 finished with value: 0.519774011299435 and parameters: {'n_estimators': 180, 'learning_rate': 0.11317181191492298, 'max_depth': 6, 'subsample': 0.9982541694750188, 'colsample_bytree': 0.8016452132179097}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:07,012] Trial 21 finished with value: 0.5536723163841808 and parameters: {'n_estimators': 146, 'learning_rate': 0.060179948551880955, 'max_depth': 7, 'subsample': 0.9326089487409536, 'colsample_bytree': 0.9405614397195942}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:07,250] Trial 22 finished with value: 0.5347593582887701 and parameters: {'n_estimators': 152, 'learning_rate': 0.023475210450027584, 'max_depth': 7, 'subsample': 0.9415214135684761, 'colsample_bytree': 0.9321838008029778}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:07,472] Trial 23 finished with value: 0.5792349726775956 and parameters: {'n_estimators': 124, 'learning_rate': 0.05245849577397355, 'max_depth': 7, 'subsample': 0.9298910014600353, 'colsample_bytree': 0.9995589570796399}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:07,651] Trial 24 finished with value: 0.5806451612903226 and parameters: {'n_estimators': 119, 'learning_rate': 0.044386301288090166, 'max_depth': 6, 'subsample': 0.9673655761970149, 'colsample_bytree': 0.9912896353180765}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:07,858] Trial 25 finished with value: 0.5760869565217391 and parameters: {'n_estimators': 119, 'learning_rate': 0.04563995198329291, 'max_depth': 7, 'subsample': 0.8067132464377816, 'colsample_bytree': 0.9984666682610599}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,052] Trial 26 finished with value: 0.5463917525773195 and parameters: {'n_estimators': 98, 'learning_rate': 0.03167433699774922, 'max_depth': 6, 'subsample': 0.9671646309364247, 'colsample_bytree': 0.9973594992338757}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,358] Trial 27 finished with value: 0.5586592178770949 and parameters: {'n_estimators': 131, 'learning_rate': 0.09540810816859345, 'max_depth': 7, 'subsample': 0.9839293776774454, 'colsample_bytree': 0.9706765628490155}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,539] Trial 28 finished with value: 0.5543478260869565 and parameters: {'n_estimators': 69, 'learning_rate': 0.05523676826780106, 'max_depth': 7, 'subsample': 0.9245733132205087, 'colsample_bytree': 0.9787835076345779}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,679] Trial 29 finished with value: 0.5028571428571429 and parameters: {'n_estimators': 88, 'learning_rate': 0.0748598065261115, 'max_depth': 6, 'subsample': 0.9475157938489345, 'colsample_bytree': 0.9576178800312322}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,781] Trial 30 finished with value: 0.5340909090909091 and parameters: {'n_estimators': 51, 'learning_rate': 0.17891001706181536, 'max_depth': 5, 'subsample': 0.8915647679925232, 'colsample_bytree': 0.985850080650098}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:08,981] Trial 31 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 121, 'learning_rate': 0.044035365150085326, 'max_depth': 7, 'subsample': 0.8150862513205742, 'colsample_bytree': 0.9994973375648817}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:09,188] Trial 32 finished with value: 0.574585635359116 and parameters: {'n_estimators': 113, 'learning_rate': 0.049236971542449035, 'max_depth': 7, 'subsample': 0.8019114801973176, 'colsample_bytree': 0.9629721980752356}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:09,388] Trial 33 finished with value: 0.5578947368421052 and parameters: {'n_estimators': 117, 'learning_rate': 0.022777431146938844, 'max_depth': 7, 'subsample': 0.8549730015736233, 'colsample_bytree': 0.9938980725136434}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:09,556] Trial 34 finished with value: 0.5549738219895288 and parameters: {'n_estimators': 106, 'learning_rate': 0.03361403447713036, 'max_depth': 6, 'subsample': 0.8360722525898269, 'colsample_bytree': 0.9498836336600583}. Best is trial 12 with value: 0.5849056603773585.
# [I 2024-06-07 10:23:09,740] Trial 35 finished with value: 0.5901639344262295 and parameters: {'n_estimators': 127, 'learning_rate': 0.06820467796385368, 'max_depth': 6, 'subsample': 0.9897260768924012, 'colsample_bytree': 0.9893899543604808}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:09,915] Trial 36 finished with value: 0.5268817204301075 and parameters: {'n_estimators': 140, 'learning_rate': 0.0678082152206951, 'max_depth': 5, 'subsample': 0.9919499306175948, 'colsample_bytree': 0.9797625471781357}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,149] Trial 37 finished with value: 0.5714285714285714 and parameters: {'n_estimators': 195, 'learning_rate': 0.11434369354404433, 'max_depth': 6, 'subsample': 0.975144133168476, 'colsample_bytree': 0.965124745080416}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,264] Trial 38 finished with value: 0.5435897435897435 and parameters: {'n_estimators': 130, 'learning_rate': 0.054599951832664126, 'max_depth': 3, 'subsample': 0.9910888925154766, 'colsample_bytree': 0.9160674533689576}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,390] Trial 39 finished with value: 0.5583756345177665 and parameters: {'n_estimators': 93, 'learning_rate': 0.03651139556389134, 'max_depth': 5, 'subsample': 0.9662687674287899, 'colsample_bytree': 0.9439778635607048}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,540] Trial 40 finished with value: 0.541871921182266 and parameters: {'n_estimators': 176, 'learning_rate': 0.021751931981126904, 'max_depth': 4, 'subsample': 0.9801970320744238, 'colsample_bytree': 0.8908198299434025}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,707] Trial 41 finished with value: 0.5652173913043478 and parameters: {'n_estimators': 105, 'learning_rate': 0.04699287536577988, 'max_depth': 6, 'subsample': 0.8748342539490466, 'colsample_bytree': 0.9884192654647685}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:10,912] Trial 42 finished with value: 0.5433526011560693 and parameters: {'n_estimators': 127, 'learning_rate': 0.07711961944706504, 'max_depth': 7, 'subsample': 0.92447599221353, 'colsample_bytree': 0.9857045437912866}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,102] Trial 43 finished with value: 0.5760869565217391 and parameters: {'n_estimators': 138, 'learning_rate': 0.06315088062182142, 'max_depth': 6, 'subsample': 0.9875076244400418, 'colsample_bytree': 0.9997307938972757}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,254] Trial 44 finished with value: 0.5621621621621622 and parameters: {'n_estimators': 78, 'learning_rate': 0.03970278258721949, 'max_depth': 7, 'subsample': 0.8985582572585359, 'colsample_bytree': 0.970833583953656}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,457] Trial 45 finished with value: 0.5355191256830601 and parameters: {'n_estimators': 119, 'learning_rate': 0.05191609923886334, 'max_depth': 7, 'subsample': 0.9992032276594799, 'colsample_bytree': 0.9880646951876231}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,617] Trial 46 finished with value: 0.5340314136125655 and parameters: {'n_estimators': 108, 'learning_rate': 0.025996701793668184, 'max_depth': 6, 'subsample': 0.9138042246536454, 'colsample_bytree': 0.9547087369284493}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,747] Trial 47 finished with value: 0.5384615384615384 and parameters: {'n_estimators': 126, 'learning_rate': 0.09563201834595542, 'max_depth': 4, 'subsample': 0.8391052805094136, 'colsample_bytree': 0.8712168934804859}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:11,936] Trial 48 finished with value: 0.5454545454545454 and parameters: {'n_estimators': 98, 'learning_rate': 0.01706960406848171, 'max_depth': 7, 'subsample': 0.8781333958481696, 'colsample_bytree': 0.8285468469775433}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:12,055] Trial 49 finished with value: 0.5482233502538071 and parameters: {'n_estimators': 62, 'learning_rate': 0.031248904980693545, 'max_depth': 6, 'subsample': 0.9497174981957882, 'colsample_bytree': 0.9267955006879242}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:12,301] Trial 50 finished with value: 0.5287356321839081 and parameters: {'n_estimators': 186, 'learning_rate': 0.06969219454229086, 'max_depth': 7, 'subsample': 0.9599216438333639, 'colsample_bytree': 0.8960846894282533}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:12,486] Trial 51 finished with value: 0.5536723163841808 and parameters: {'n_estimators': 138, 'learning_rate': 0.0633984785698683, 'max_depth': 6, 'subsample': 0.9915096530247859, 'colsample_bytree': 0.9999897216433304}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:12,684] Trial 52 finished with value: 0.5303867403314917 and parameters: {'n_estimators': 144, 'learning_rate': 0.05979790125525088, 'max_depth': 6, 'subsample': 0.986233594453514, 'colsample_bytree': 0.9931254024959928}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:12,852] Trial 53 finished with value: 0.5027322404371585 and parameters: {'n_estimators': 163, 'learning_rate': 0.042045706408365704, 'max_depth': 5, 'subsample': 0.9708210323131828, 'colsample_bytree': 0.9786377338582233}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:13,044] Trial 54 finished with value: 0.5227272727272727 and parameters: {'n_estimators': 135, 'learning_rate': 0.08753481700452516, 'max_depth': 6, 'subsample': 0.9851228762987657, 'colsample_bytree': 0.9706410500752006}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:13,240] Trial 55 finished with value: 0.5649717514124294 and parameters: {'n_estimators': 125, 'learning_rate': 0.08141131240353626, 'max_depth': 7, 'subsample': 0.974199127658183, 'colsample_bytree': 0.9907537011937742}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:13,403] Trial 56 finished with value: 0.574468085106383 and parameters: {'n_estimators': 113, 'learning_rate': 0.04907127495899763, 'max_depth': 6, 'subsample': 0.9383822999448703, 'colsample_bytree': 0.9795307059385029}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:13,633] Trial 57 finished with value: 0.5444444444444444 and parameters: {'n_estimators': 152, 'learning_rate': 0.06356081529337439, 'max_depth': 7, 'subsample': 0.9620002214432538, 'colsample_bytree': 0.8612072537682136}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:13,787] Trial 58 finished with value: 0.5280898876404494 and parameters: {'n_estimators': 117, 'learning_rate': 0.07264862579974277, 'max_depth': 6, 'subsample': 0.9922800675617651, 'colsample_bytree': 0.9061671684433659}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:14,001] Trial 59 finished with value: 0.5851063829787234 and parameters: {'n_estimators': 134, 'learning_rate': 0.017160794905610167, 'max_depth': 7, 'subsample': 0.9529646008858361, 'colsample_bytree': 0.8377547793983251}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:14,228] Trial 60 finished with value: 0.5625 and parameters: {'n_estimators': 132, 'learning_rate': 0.015814937566029925, 'max_depth': 7, 'subsample': 0.9534291208144214, 'colsample_bytree': 0.8104474165467169}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:14,433] Trial 61 finished with value: 0.5483870967741935 and parameters: {'n_estimators': 141, 'learning_rate': 0.02775218821320684, 'max_depth': 7, 'subsample': 0.9789399336366977, 'colsample_bytree': 0.8370417086707329}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:14,634] Trial 62 finished with value: 0.572972972972973 and parameters: {'n_estimators': 135, 'learning_rate': 0.037501222523734626, 'max_depth': 7, 'subsample': 0.9660611433923486, 'colsample_bytree': 0.8188693890059898}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:14,850] Trial 63 finished with value: 0.5454545454545454 and parameters: {'n_estimators': 148, 'learning_rate': 0.16349703664999304, 'max_depth': 7, 'subsample': 0.9416156590194904, 'colsample_bytree': 0.8420076386217592}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:15,087] Trial 64 finished with value: 0.5520833333333334 and parameters: {'n_estimators': 157, 'learning_rate': 0.016909319178630314, 'max_depth': 7, 'subsample': 0.9328809284192449, 'colsample_bytree': 0.8218476482804735}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:15,316] Trial 65 finished with value: 0.5513513513513514 and parameters: {'n_estimators': 200, 'learning_rate': 0.04444146710742063, 'max_depth': 6, 'subsample': 0.954911306362751, 'colsample_bytree': 0.8561066496910443}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:15,518] Trial 66 finished with value: 0.5586592178770949 and parameters: {'n_estimators': 121, 'learning_rate': 0.05584735649518261, 'max_depth': 7, 'subsample': 0.9821738064054926, 'colsample_bytree': 0.9994595911259744}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:15,673] Trial 67 finished with value: 0.5687203791469194 and parameters: {'n_estimators': 129, 'learning_rate': 0.01065936372188949, 'max_depth': 5, 'subsample': 0.969668701762146, 'colsample_bytree': 0.984476818739141}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:15,847] Trial 68 finished with value: 0.5347593582887701 and parameters: {'n_estimators': 112, 'learning_rate': 0.02816877402298226, 'max_depth': 6, 'subsample': 0.864164506372392, 'colsample_bytree': 0.87326772345517}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,084] Trial 69 finished with value: 0.5291005291005291 and parameters: {'n_estimators': 143, 'learning_rate': 0.020506304120060534, 'max_depth': 7, 'subsample': 0.823608972566088, 'colsample_bytree': 0.9722149529524898}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,206] Trial 70 finished with value: 0.5051546391752577 and parameters: {'n_estimators': 125, 'learning_rate': 0.0355047385660167, 'max_depth': 4, 'subsample': 0.988128052733691, 'colsample_bytree': 0.9939164217430291}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,408] Trial 71 finished with value: 0.5573770491803278 and parameters: {'n_estimators': 110, 'learning_rate': 0.04803666587845063, 'max_depth': 7, 'subsample': 0.8081721818095985, 'colsample_bytree': 0.9647586325231424}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,613] Trial 72 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 122, 'learning_rate': 0.051723899048900415, 'max_depth': 7, 'subsample': 0.8012255935499829, 'colsample_bytree': 0.9847094086259444}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,801] Trial 73 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 103, 'learning_rate': 0.05925864658567673, 'max_depth': 7, 'subsample': 0.8211214359774622, 'colsample_bytree': 0.9639775959025149}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:16,984] Trial 74 finished with value: 0.5901639344262295 and parameters: {'n_estimators': 116, 'learning_rate': 0.04000629907840559, 'max_depth': 7, 'subsample': 0.8025533225565377, 'colsample_bytree': 0.9933190852756502}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:17,184] Trial 75 finished with value: 0.5683060109289617 and parameters: {'n_estimators': 116, 'learning_rate': 0.04167530199733267, 'max_depth': 7, 'subsample': 0.8083323882874859, 'colsample_bytree': 0.9951735871824077}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:17,399] Trial 76 finished with value: 0.5319148936170213 and parameters: {'n_estimators': 133, 'learning_rate': 0.030506557264787487, 'max_depth': 7, 'subsample': 0.9964332151061055, 'colsample_bytree': 0.9911461375329599}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:17,588] Trial 77 finished with value: 0.5649717514124294 and parameters: {'n_estimators': 137, 'learning_rate': 0.12752637179050663, 'max_depth': 6, 'subsample': 0.9758518005711243, 'colsample_bytree': 0.9837895394842324}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:17,784] Trial 78 finished with value: 0.5591397849462365 and parameters: {'n_estimators': 98, 'learning_rate': 0.03728194602256088, 'max_depth': 7, 'subsample': 0.8464876549161326, 'colsample_bytree': 0.836475358171246}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:17,936] Trial 79 finished with value: 0.5638297872340425 and parameters: {'n_estimators': 90, 'learning_rate': 0.0658138042577702, 'max_depth': 5, 'subsample': 0.9113564252697314, 'colsample_bytree': 0.9735300075203103}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:18,079] Trial 80 finished with value: 0.5538461538461539 and parameters: {'n_estimators': 71, 'learning_rate': 0.021563791259763994, 'max_depth': 6, 'subsample': 0.813885815634156, 'colsample_bytree': 0.9962481495079536}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:18,313] Trial 81 finished with value: 0.5760869565217391 and parameters: {'n_estimators': 115, 'learning_rate': 0.052039211555989125, 'max_depth': 7, 'subsample': 0.8009962048512996, 'colsample_bytree': 0.9828466937911848}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:18,557] Trial 82 finished with value: 0.5444444444444444 and parameters: {'n_estimators': 130, 'learning_rate': 0.054946789400981556, 'max_depth': 7, 'subsample': 0.8067960236685471, 'colsample_bytree': 0.9818035831324691}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:18,784] Trial 83 finished with value: 0.5698324022346368 and parameters: {'n_estimators': 118, 'learning_rate': 0.04570597451247713, 'max_depth': 7, 'subsample': 0.8280694841401465, 'colsample_bytree': 0.989478691988888}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:19,025] Trial 84 finished with value: 0.5384615384615384 and parameters: {'n_estimators': 123, 'learning_rate': 0.07780516076315745, 'max_depth': 7, 'subsample': 0.8144724360364821, 'colsample_bytree': 0.9998747094016867}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:19,167] Trial 85 finished with value: 0.5621621621621622 and parameters: {'n_estimators': 54, 'learning_rate': 0.06838698336545082, 'max_depth': 7, 'subsample': 0.9204910620672317, 'colsample_bytree': 0.9772407551461735}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:19,401] Trial 86 finished with value: 0.5792349726775956 and parameters: {'n_estimators': 128, 'learning_rate': 0.06032189472668909, 'max_depth': 7, 'subsample': 0.9952439608619041, 'colsample_bytree': 0.9888135523280174}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:19,567] Trial 87 finished with value: 0.5297297297297298 and parameters: {'n_estimators': 83, 'learning_rate': 0.08741175422053142, 'max_depth': 6, 'subsample': 0.9961757867005321, 'colsample_bytree': 0.9909511833021593}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:19,807] Trial 88 finished with value: 0.5714285714285714 and parameters: {'n_estimators': 128, 'learning_rate': 0.03303264885278421, 'max_depth': 7, 'subsample': 0.9629700662430882, 'colsample_bytree': 0.9237769416066749}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:20,034] Trial 89 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 139, 'learning_rate': 0.06114902336640999, 'max_depth': 7, 'subsample': 0.9999129989607236, 'colsample_bytree': 0.9956753755281288}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:20,227] Trial 90 finished with value: 0.5445544554455446 and parameters: {'n_estimators': 109, 'learning_rate': 0.016247741301503225, 'max_depth': 6, 'subsample': 0.9811109616557034, 'colsample_bytree': 0.9593799846503933}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:20,456] Trial 91 finished with value: 0.5824175824175825 and parameters: {'n_estimators': 115, 'learning_rate': 0.056979388233743725, 'max_depth': 7, 'subsample': 0.8051092995413817, 'colsample_bytree': 0.987935457117837}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:20,672] Trial 92 finished with value: 0.5524861878453039 and parameters: {'n_estimators': 120, 'learning_rate': 0.05696251340672, 'max_depth': 7, 'subsample': 0.9895316594708918, 'colsample_bytree': 0.9877757991529016}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:20,897] Trial 93 finished with value: 0.5760869565217391 and parameters: {'n_estimators': 126, 'learning_rate': 0.03995107465719154, 'max_depth': 7, 'subsample': 0.9935120544836595, 'colsample_bytree': 0.9763065168402056}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:21,134] Trial 94 finished with value: 0.5513513513513514 and parameters: {'n_estimators': 134, 'learning_rate': 0.07172502019515076, 'max_depth': 7, 'subsample': 0.818427805113474, 'colsample_bytree': 0.9924295375017455}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:21,395] Trial 95 finished with value: 0.5638297872340425 and parameters: {'n_estimators': 146, 'learning_rate': 0.025373941450030503, 'max_depth': 7, 'subsample': 0.9841169784556234, 'colsample_bytree': 0.8016639184127742}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:21,623] Trial 96 finished with value: 0.5402298850574713 and parameters: {'n_estimators': 123, 'learning_rate': 0.08156122804542239, 'max_depth': 7, 'subsample': 0.9259591682588387, 'colsample_bytree': 0.8439221143427967}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:21,800] Trial 97 finished with value: 0.5795454545454546 and parameters: {'n_estimators': 103, 'learning_rate': 0.0636962052556526, 'max_depth': 6, 'subsample': 0.9765351415526052, 'colsample_bytree': 0.968891659401803}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:22,017] Trial 98 finished with value: 0.5513513513513514 and parameters: {'n_estimators': 101, 'learning_rate': 0.05181002705331624, 'max_depth': 7, 'subsample': 0.9037493596997249, 'colsample_bytree': 0.9688377529829014}. Best is trial 35 with value: 0.5901639344262295.
# [I 2024-06-07 10:23:22,144] Trial 99 finished with value: 0.5588235294117647 and parameters: {'n_estimators': 105, 'learning_rate': 0.045467506432662896, 'max_depth': 3, 'subsample': 0.9748953154397789, 'colsample_bytree': 0.9497470353772055}. Best is trial 35 with value: 0.5901639344262295.
# Best parameters: {'n_estimators': 127, 'learning_rate': 0.06820467796385368, 'max_depth': 6, 'subsample': 0.9897260768924012, 'colsample_bytree': 0.9893899543604808}
# Best score: 0.5901639344262295

# %% [markdown]
# # Cross-validation

# %%
kf = KFold(n_splits=5) #k-fold cross-validation with k=5
Models={'Decision tree':DecisionTreeClassifier(**{'criterion': 'entropy', 'splitter': 'best', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 20}),
        'Random Forest':RandomForestClassifier(**{'n_estimators': 90, 'max_depth': 1, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}),
        'Logistic regression':LogisticRegression(**{'C': 0.00010030785637449065, 'penalty': 'l1'},max_iter=10000,solver = 'liblinear'),
        'XGBoost': XGBClassifier(**{'n_estimators': 127, 'learning_rate': 0.06820467796385368, 'max_depth': 6, 'subsample': 0.9897260768924012, 'colsample_bytree': 0.9893899543604808})}

# %%
scores={k: [] for k in Models}
for k in scores:
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = Y.iloc[train_index], Y.iloc[test_index]
        model=Models[k]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        scores[k].append(f1_score(y_test, y_pred))
scores={k: np.mean(v) for k,v in scores.items()}

# %%
scores
# Out:
# {'Decision tree': 0.4970327424713947,
#  'Random Forest': 0.6945006422648758,
#  'Logistic regression': 0.6941348204723491,
#  'XGBoost': 0.4965655487985585}

# %% [markdown]
# After cross-validation, we conclude that the best models are Random Forest and Logistic regression

# %%
#fitting the two selected models on the whole training set
model_regress=Models['Logistic regression']
model_random_forest=Models['Random Forest']
model_regress.fit(X,Y)
model_random_forest.fit(X,Y)
# Out:
# RandomForestClassifier(max_depth=1, max_features=None, min_samples_leaf=3,
#                        min_samples_split=10, n_estimators=90)

# %% [markdown]
# # Preparing the test set

# %%
test=pd.read_csv('test.csv')

# %%
#Handling missing values
test['Date']=pd.to_datetime(test['Date'].values)
test.set_index('Date',inplace=True)
test.interpolate(method='time',inplace=True)
test.reset_index()

# %%
test=pd.merge(sentiment_result, test, on='Date', how='inner')

# %%
test
# Out:
#           Date  Sentiment        CL=F  EURUSD=X         GC=F      HG=F  \
# 0   2011-08-08  -0.673077   81.309998  1.429409  1710.199951  3.957500
# 1   2011-08-09   0.413793   79.300003  1.417073  1740.000000  3.967000
# 2   2011-08-10  -0.407407   82.889999  1.438311  1781.300049  3.885500
# 3   2011-08-11  -0.347826   85.720001  1.412469  1748.800049  4.004500
# 4   2011-08-12   0.068966   85.379997  1.422637  1740.199951  4.009500
# ..         ...        ...         ...       ...          ...       ...
# 100 2011-12-26   0.800000  100.924997  1.304495  1596.824951  3.418875
# 101 2011-12-27  -0.533333  101.339996  1.305057  1594.199951  3.404000
# 102 2011-12-28  -0.862069   99.360001  1.307207  1562.900024  3.360000
# 103 2011-12-29   0.296296   99.650002  1.292725  1539.900024  3.365500
# 104 2011-12-30  -0.366667   98.830002  1.295605  1565.800049  3.431500
#
#          JPY=X       SI=F     XWD.TO          ^DJI        ^GSPC        ^IXIC  \
# 0    78.253998  39.374001  20.521042  10809.849609  1119.459961  2357.689941
# 1    77.584999  37.876999  21.162325  11239.769531  1172.530029  2482.520020
# 2    77.050003  39.325001  20.591183  10719.940430  1120.760010  2381.050049
# 3    76.759003  38.655998  21.412827  11143.309570  1172.640015  2492.679932
# 4    76.860001  39.101002  21.653307  11269.019531  1178.810059  2507.979980
# ..         ...        ...        ...           ...          ...          ...
# 100  78.080002  28.784250  22.174349  12292.012207  1265.405029  2623.559937
# 101  78.029999  28.697001  22.174349  12291.349609  1265.430054  2625.199951
# 102  77.870003  27.191999  22.174349  12151.410156  1249.640015  2589.979980
# 103  77.945999  27.274000  22.134270  12287.040039  1263.020020  2613.739990
# 104  77.658997  27.875000  22.194389  12217.559570  1257.599976  2605.149902
#
#            ^RUT     ^TNX     ^TYX       ^VIX
# 0    650.960022  2.33900  3.66300  48.000000
# 1    696.159973  2.18200  3.57300  35.060001
# 2    660.210022  2.13700  3.53800  42.990002
# 3    695.890015  2.33600  3.78700  39.000000
# 4    697.500000  2.23700  3.70300  36.360001
# ..          ...      ...      ...        ...
# 100  750.477493  2.01425  3.04525  21.615000
# 101  751.309998  2.00900  3.03900  21.910000
# 102  735.210022  1.90800  2.89700  23.520000
# 103  744.979980  1.89700  2.90700  22.650000
# 104  740.919983  1.87100  2.88900  23.400000
#
# [105 rows x 16 columns]

# %%
X = test[L]
Y_regress = model_regress.predict(X)
Y_random_forest=model_random_forest.predict(X)

# %% [markdown]
# Creating file for logistic regression

# %%
test['target']=Y_regress

# %%
test['id']=test.index.values

# %%
test[['id','target']].to_csv('submission_regression.csv',index=False)

# %% [markdown]
# and for random forest

# %%
test['target']=Y_random_forest
test[['id','target']].to_csv('submission_random_forest.csv',index=False)
